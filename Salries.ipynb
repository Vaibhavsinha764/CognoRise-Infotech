# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.sort_values(by='salary_in_usd',ascending=False,inplace=True)

# %%
df.head()
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
# 97           97       2021               MI              FT
# 33           33       2020               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 97               Financial Data Analyst  450000             USD
# 33                   Research Scientist  450000             USD
# 157  Applied Machine Learning Scientist  423000             USD
# 225            Principal Data Scientist  416000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 252         600000                 US           100               US
# 97          450000                 US           100               US
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 179         179       2021               MI              FT
# 77           77       2021               MI              PT
# 238         238       2021               EN              FT
# 185         185       2021               MI              FT
# 176         176       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 179                 Data Scientist  420000             INR           5679
# 77   3D Computer Vision Researcher  400000             INR           5409
# 238                 Data Scientist    4000             USD           4000
# 185                  Data Engineer    4000             USD           4000
# 176                 Data Scientist   58000             MXN           2859
#
#     employee_residence  remote_ratio company_location company_size
# 179                 IN           100               US            S
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed':'S.No.'},inplace=True)

# %%
df.head()
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
# 97           97       2021               MI              FT
# 33           33       2020               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 97               Financial Data Analyst  450000             USD
# 33                   Research Scientist  450000             USD
# 157  Applied Machine Learning Scientist  423000             USD
# 225            Principal Data Scientist  416000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 252         600000                 US           100               US
# 97          450000                 US           100               US
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %% [markdown]
# # highest salary in USD for job title (Top 3)

# %%
df.head(3).plot(x='job_title', y='salary', kind='line')
plt.title('Yearly Salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Lowest Paid Jobs

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
# 97           97       2021               MI              FT
# 33           33       2020               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
# ..          ...        ...              ...             ...
# 179         179       2021               MI              FT
# 77           77       2021               MI              PT
# 238         238       2021               EN              FT
# 185         185       2021               MI              FT
# 176         176       2021               MI              FT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 97               Financial Data Analyst  450000             USD
# ...

# %%
df.tail(10).set_index('job_title')['salary_in_usd'].plot.pie(autopct='%1.1f%%', startangle=90)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.gca().set_aspect('equal')

# Display the chart
plt.show()

# %% [markdown]
# # Average salary

# %%
df1=df.head()

# %%
df1.head()
# Out:
#      Unnamed: 0                     work_year experience_level  \
# 252         252 1970-01-01 00:00:00.000002021               EX
# 97           97 1970-01-01 00:00:00.000002021               MI
# 33           33 1970-01-01 00:00:00.000002020               MI
# 157         157 1970-01-01 00:00:00.000002021               MI
# 225         225 1970-01-01 00:00:00.000002021               EX
#
#     employment_type                           job_title  salary  \
# 252              FT             Principal Data Engineer  600000
# 97               FT              Financial Data Analyst  450000
# 33               FT                  Research Scientist  450000
# 157              FT  Applied Machine Learning Scientist  423000
# 225              CT            Principal Data Scientist  416000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 252             USD         600000                 US           100
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
sns.boxplot(x='salary_in_usd',y='employment_type',data=df)
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='employment_type'>

# %% [markdown]
# # Experince in the field of their job till 2024

# %%
df
# Out:
#      Unnamed: 0                     work_year experience_level  \
# 252         252 1970-01-01 00:00:00.000002021               EX
# 97           97 1970-01-01 00:00:00.000002021               MI
# 33           33 1970-01-01 00:00:00.000002020               MI
# 157         157 1970-01-01 00:00:00.000002021               MI
# 225         225 1970-01-01 00:00:00.000002021               EX
# ..          ...                           ...              ...
# 179         179 1970-01-01 00:00:00.000002021               MI
# 77           77 1970-01-01 00:00:00.000002021               MI
# 238         238 1970-01-01 00:00:00.000002021               EN
# 185         185 1970-01-01 00:00:00.000002021               MI
# 176         176 1970-01-01 00:00:00.000002021               MI
#
#     employment_type                           job_title  salary  \
# 252              FT             Principal Data Engineer  600000
# 97               FT              Financial Data Analyst  450000
# ...

# %%
df['work_year'] = pd.to_datetime(df['work_year'])
df['Normalized Date'] = df['work_year'].dt.normalize()
df.head()
# Out:
#      Unnamed: 0                     work_year experience_level  \
# 252         252 1970-01-01 00:00:00.000002021               EX
# 97           97 1970-01-01 00:00:00.000002021               MI
# 33           33 1970-01-01 00:00:00.000002020               MI
# 157         157 1970-01-01 00:00:00.000002021               MI
# 225         225 1970-01-01 00:00:00.000002021               EX
#
#     employment_type                           job_title  salary  \
# 252              FT             Principal Data Engineer  600000
# 97               FT              Financial Data Analyst  450000
# 33               FT                  Research Scientist  450000
# 157              FT  Applied Machine Learning Scientist  423000
# 225              CT            Principal Data Scientist  416000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 252             USD         600000                 US           100
# ...

# %%
df['Start_Date'] = pd.to_datetime(df['Start_Date'])

# %%
sns.scatterplot(x='salary_in_usd', y='experience_level', data=df)

plt.show()
